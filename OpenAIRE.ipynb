# %%
import pandas as pd
import openaire as oa

refresh_token = open("secret.txt", "r").read()
# get your own from: https://develop.openaire.eu/personal-token

keywords = 'categorisation'

df = oa.get_openaire_df(keywords='categorisation', size=100)

# %%
df
# Out:
#                                                 Title  \
# 0   Categorisation Work in the Courtroom The ‘Foun...
# 1              Categorisation, a fundamental process.
# 2   Perceptual and functional categorisation in as...
# 3   Attentional control in categorisation: towards...
# 4            Scene categorisation for video retrieval
# ..                                                ...
# 95  Categorisation of natural sounds at different ...
# 96  Osteogenesis imperfecta in Southern Africa. Di...
# 97  Changing perceptions? Effects of multiple soci...
# 98  Categorisation of built environment characteri...
# 99  EVIDENCE OF EXPLICITATION IN SUBTITLING: TOWAR...
#
#                                               Authors Publication Year  \
# 0                                   Christian Licoppe       2015-01-01
# 1                                 Urdapilleta, Isabel       2011-01-01
# 2                               Grand, Christopher S.              NaN
# ...
